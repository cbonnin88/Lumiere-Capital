-- %%
-- Where the money is currently sitting

SELECT
  sector,
  SUM(amount_invested_eur) AS total_invested,
  COUNT(company_name) AS portfolio_companies
FROM lumiere_capital.dbt_lumiere_capital.fct_portfolio_performance
GROUP BY 1
ORDER BY total_invested DESC;
