-- %%
-- Companies where the current value is less than what we paid (MOIC <1.0)
SELECT
  company_name,
  amount_invested_eur,
  current_estimated_value,
  moic
FROM lumiere_capital.dbt_lumiere_capital.fct_portfolio_performance
WHERE moic < 1.0
ORDER BY moic ASC;
